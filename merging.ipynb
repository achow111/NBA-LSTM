# %%
import pandas as pd

# %%
# %run get_team_data.ipynb

# %%
# %run get_team_data.ipynb

# %%
game_logs
# Out:
#             Name       Date  Age   Tm                  Opp Win/Loss  \
# 0   Jakob Poeltl 2016-10-26   21  TOR      Detroit Pistons  W (+18)
# 1   Jakob Poeltl 2016-10-28   21  TOR  Cleveland Cavaliers   L (-3)
# 2   Jakob Poeltl 2016-10-31   21  TOR       Denver Nuggets   W (+3)
# 3   Jakob Poeltl 2016-11-02   21  TOR   Washington Wizards  W (+10)
# 4   Jakob Poeltl 2016-11-04   21  TOR           Miami Heat   W (+9)
# ..           ...        ...  ...  ...                  ...      ...
# 76   Bruce Brown 2024-04-07   27  TOR   Washington Wizards   W (+8)
# 77   Bruce Brown 2024-04-09   27  TOR       Indiana Pacers  L (-17)
# 78   Bruce Brown 2024-04-10   27  TOR        Brooklyn Nets   L (-4)
# 79   Bruce Brown 2024-04-12   27  TOR           Miami Heat  L (-22)
# 80   Bruce Brown 2024-04-14   27  TOR           Miami Heat  L (-15)
#
#                GS             MP             FG            FGA  ...  \
# 0               0          12:47              1              4  ...
# ...

# %%
advanced_stats
# Out:
#       Rk                    Team   Age     W     L  PW  PL    MOV   SOS  \
# 0    1.0       San Antonio Spurs  27.3  57.0  25.0  62  20   7.22  0.29
# 1    2.0         Detroit Pistons  27.4  54.0  28.0  59  23   5.84 -0.81
# 2    3.0          Indiana Pacers  27.1  61.0  21.0  58  24   5.76 -0.82
# 3    4.0  Minnesota Timberwolves  29.7  58.0  24.0  57  25   5.49  0.37
# 4    5.0        Sacramento Kings  29.3  55.0  27.0  55  27   5.01  0.40
# ..   ...                     ...   ...   ...   ...  ..  ..    ...   ...
# 25  26.0      Philadelphia 76ers  28.7   3.0  14.0   4  13  -8.29  1.60
# 26  27.0  Portland Trail Blazers  24.2   7.0  12.0   5  14  -8.42  1.10
# 27  28.0               Utah Jazz  24.7   4.0  14.0   4  14  -9.83  2.09
# 28  29.0    New Orleans Pelicans  25.7   4.0  15.0   3  16 -11.79  0.94
# 29  30.0      Washington Wizards  23.6   2.0  15.0   2  15 -15.29  1.87
#
#       SRS  ...   eFG%  TOV%  ORB%  FT/FGA  eFG%.1  TOV%.1  DRB%  FT/FGA.1  \
# ...

# %%
print(game_logs.columns)
# Out:
# Index(['Name', 'Date', 'Age', 'Tm', 'Opp', 'Win/Loss', 'GS', 'MP', 'FG', 'FGA',
#        'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'GmSc', '+/-',
#        'Player Encoding'],
#       dtype='object')

# %%
print(advanced_stats.columns)
# Out:
# Index(['Rk', 'Team', 'Age', 'W', 'L', 'PW', 'PL', 'MOV', 'SOS', 'SRS', 'ORtg',
#        'DRtg', 'NRtg', 'Pace', 'FTr', '3PAr', 'TS%', 'eFG%', 'TOV%', 'ORB%',
#        'FT/FGA', 'eFG%.1', 'TOV%.1', 'DRB%', 'FT/FGA.1', 'Year',
#        'Team Encode'],
#       dtype='object')

# %%
merged = pd.merge(game_logs, advanced_stats, how='right',left_on=['Year', 'Opp'],right_on=['Year', 'Team'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/s3/wsjvqqc12gqbvck8cdc_sh_80000gn/T/ipykernel_74814/3160336037.py in ?()
# ----> 1 merged = pd.merge(game_logs, advanced_stats, how='right',left_on=['Year', 'Opp'],right_on=['Year', 'Team'])
#
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# ...
